# %% [markdown]
# # OCT triage exploration
#
# Use this notebook for quick EDA: class counts, sample visualizations, and sanity checks on `data/raw/` before training.
#
# **Reminder:** educational project only — not for clinical use.

# %%
from pathlib import Path

from src import config

print("Project root:", config.PROJECT_ROOT)
print("Train dir:", config.TRAIN_DIR)
